# %%
import pandas as pd
from tqdm.notebook import tqdm

from transformers import BertModel, BertTokenizer
import torch
import glob, os, re

from parallel_pandas import ParallelPandas
from functools import partial

import helpers

# %%
ParallelPandas.initialize(n_cpu=23, split_factor=4)

# %% [markdown]
# ## Load in transcripts

# %%
files = glob.glob("../raw/[0-9]*.csv")

# %%
dfs = []
for fi in tqdm(files):
    try:
        df = pd.read_csv(fi, index_col=0)
    except Exception:
        df = pd.read_csv(fi, encoding="windows-1252", index_col=0)
    dfs.append(df)
full_data = pd.concat(dfs, axis = 0)
# Out:
#   0%|          | 0/701 [00:00<?, ?it/s]

# %%
full_data.head()
# Out:
#   LineNo            Interviewer Statement  \
# 0   1291          The Chairman.       NaN
# 1   1292          The Chairman.       NaN
# 2   1293  Mr Fraser-Mackintosh.       NaN
# 3   1294          The Chairman.       NaN
# 4   1295      Sheriff Nicolson.       NaN
#
#                                             Question  \
# 0                          What is your occupation ?
# 1           How far back with the previous landlord?
# 2                 We will take the present landlord?
# 3  Will you state the amount of stock which your ...
# 4                When were the sheep taken from you?
#
#                                               Answer  Vol  Page  \
# 0  My son is a crofter, and I am in my son's plac...  1.0  73.0
# 1                             Thirty-four years ago.  1.0  73.0
# 2  The present landlord raised our rent 31s. and ...  1.0  73.0
# 3  In summer and autumn we could keep two cows an...  1.0  73.0
# 4  The landlord took the sheep stock from us a fe...  1.0  73.0
#
#              Area     Witness            Location
# 0  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 1  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 2  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 3  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 4  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale

# %%
place_constructs = pd.read_csv("../data/place_identity_community.csv")
place_constructs = place_constructs.dropna()
place_constructs
# Out:
#                                         question_text        type
# 0                I am very attached to this community    identity
# 1                This community is very special to me    identity
# 2             I identify strongly with this community    identity
# 3               I feel this community is a part of me    identity
# 4                    This community means a lot to me    identity
# 5   Living in this community says a lot about who ...    identity
# 6                 I identify strongly with this place    identity
# 7                   The town is like a part of myself    identity
# 8                  This factor is part of my identity    identity
# 9            My bonds to this part of town are strong    identity
# 10  This community is the best place for what I li...  dependence
# 11       No other place can compare to this community  dependence
# 12  I wouldn't substitute any other community for ...  dependence
# 13  I get more satisfaction living in this communi...  dependence
# 14  Doing what I do at this community is more impo...  dependence
# 15  The things I do at this community I would enjo...  dependence

# %%
place_constructs = pd.read_csv("../data/place_identity_land.csv")
place_constructs = place_constructs.dropna()
place_constructs
# Out:
#                                         question_text        type
# 0                     I am very attached to this land    identity
# 1                     This land is very special to me    identity
# 2                  I identify strongly with this land    identity
# 3                    I feel this land is a part of me    identity
# 4                         This land means a lot to me    identity
# 5       Living in this land says a lot about who I am    identity
# 6                  I identify strongly with this land    identity
# 7                   The land is like a part of myself    identity
# 8                    This land is part of my identity    identity
# 9            My bonds to this part of land are strong    identity
# 10  This land is the best place for what I like to do  dependence
# 11           No other placce can compare to this land  dependence
# 12  I wouldn't substitute any other land for doing...  dependence
# 13  I get more satisfaction living in this land th...  dependence
# 14  Doing what I do at this land is more important...  dependence
# 15  The things I do at this land I would enjoy doi...  dependence

# %%
full_text = full_data.dropna(subset=["Answer"]).groupby(["Area", "Location", "Witness"])["Answer"].apply(lambda x: "\n".join(x)).reset_index(name="text")
full_text.head()
# Out:
#                      Area    Location                                Witness  \
# 0  Argyll, Bunessan, Mull  Ardalanish                     Alexander Mcintyre
# 1  Argyll, Bunessan, Mull      Ardtun       Duncan Mclean, Lachlan Macdonald
# 2  Argyll, Bunessan, Mull    Bunessan  Alexander Mckechnie, MB, CM (Glasgow)
# 3  Argyll, Bunessan, Mull    Bunessan                          Neil Matheson
# 4  Argyll, Bunessan, Mull    Catchean          John Mccormick, John Mckinnon
#
#                                                 text
# 0  For the last 300 years.\nNo; they were born an...
# 1  No.\nThe only thing we have to say is that we ...
# 2  Over six years.\nNo; I was in Inverness.\nI ha...
# 3  I  have been a fisherman from my youth, and th...
# 4  Nine.\n. There are some of them sub-tenants.\n...

# %%
full_text = full_data.dropna(subset=["Answer"])
full_text.head()
# Out:
#   LineNo            Interviewer Statement  \
# 0   1291          The Chairman.       NaN
# 1   1292          The Chairman.       NaN
# 2   1293  Mr Fraser-Mackintosh.       NaN
# 3   1294          The Chairman.       NaN
# 4   1295      Sheriff Nicolson.       NaN
#
#                                             Question  \
# 0                          What is your occupation ?
# 1           How far back with the previous landlord?
# 2                 We will take the present landlord?
# 3  Will you state the amount of stock which your ...
# 4                When were the sheep taken from you?
#
#                                               Answer  Vol  Page  \
# 0  My son is a crofter, and I am in my son's plac...  1.0  73.0
# 1                             Thirty-four years ago.  1.0  73.0
# 2  The present landlord raised our rent 31s. and ...  1.0  73.0
# 3  In summer and autumn we could keep two cows an...  1.0  73.0
# 4  The landlord took the sheep stock from us a fe...  1.0  73.0
#
#              Area     Witness            Location
# 0  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 1  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 2  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 3  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale
# 4  Skye, Skeabost  Hugh Mcnab  Kildonan, Lynedale

# %%
tqdm.pandas(desc="Cosine sim")
cosine_sims = full_text["Answer"].p_apply(helpers.compute_place_identity_measure)
# Out:
# COMPUTE_PLACE_IDENTITY_MEASURE DONE:   0%|          | 0/43678 [00:00<?, ?it/s]

# %%
pd.concat([full_text, cosine_sims], axis = 1).to_csv("cosine_sim.csv", index = False)
